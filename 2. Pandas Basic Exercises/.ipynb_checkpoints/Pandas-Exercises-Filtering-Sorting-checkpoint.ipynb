# %% [markdown]
# # Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset *chipotle.tsv*

# %%
chipo = pd.read_table("chipotle.tsv",sep="\t")
chipo
# Out:
# /Users/mayur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?
#
# Use `str` attribute to remove the $ sign and convert the column to proper numeric type data before filtering.

# %%
chipo['item_price'] = chipo['item_price'].astype(str)
chipo['item_price'] = chipo['item_price'].str.replace('$','')
chipo['item_price'] = pd.to_numeric(df['item_price'])
item = chipo[(chipo['item_price']>10)]
total = len(item)
print('Number of products which cost more than $10.00 is : ',total)
# Out:
# Number of products which cost more than $10.00 is :  1130

# %% [markdown]
# ### Step 5. What is the price of each item?
#
# print a data frame with only two columns `item_name` and `item_price`

# %%
df = pd.DataFrame(chipo)
f = df[['item_name','item_price']]
f
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# 5                              Chicken Bowl       10.98
# 6                             Side of Chips        1.69
# 7                             Steak Burrito       11.75
# 8                          Steak Soft Tacos        9.25
# 9                             Steak Burrito        9.25
# 10                      Chips and Guacamole        4.45
# 11                     Chicken Crispy Tacos        8.75
# 12                       Chicken Soft Tacos        8.75
# 13                             Chicken Bowl       11.25
# 14                      Chips and Guacamole        4.45
# 15    Chips and Tomatillo-Green Chili Salsa        2.39
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
df.sort_values(by ='item_name',axis = 0,ascending = True)
df
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 3141      1253         1  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# 1922       776         1  6 Pack Soft Drink
# 1937       784         1  6 Pack Soft Drink
# 3836      1537         1  6 Pack Soft Drink
# 298        129         1  6 Pack Soft Drink
# 2389       949         1  6 Pack Soft Drink
# 4363      1742         1  6 Pack Soft Drink
# 553        230         1  6 Pack Soft Drink
# 3422      1373         1  6 Pack Soft Drink
# 1976       798         1  6 Pack Soft Drink
# 3875      1554         1  6 Pack Soft Drink
# 1167       481         1  6 Pack Soft Drink
# 4522      1798         1  6 Pack Soft Drink
# 4174      1666         1  6 Pack Soft Drink
# 4527      1800         1  6 Pack Soft Drink
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
df.sort_values(by = 'item_price',ascending = False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %% [markdown]
# ### Step 8. How many times were a Veggie Salad Bowl ordered?

# %%
chipo_salad = df[df.item_name == 'Veggie Salad Bowl']
len(chipo_salad)
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times people orderd more than one Canned Soda?

# %%
chipo_soda = df[(df.item_name == "Canned Soda") & (df.quantity > 1)]
len(chipo_soda)
# Out:
# 20
