# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Q1 In the above dataset :
#
# ### a. In case age is less than 18, replace it with mean of age values.

# %%
Customer_Acq = pd.read_csv("Customer Acqusition.csv")

# %%
df = pd.DataFrame(Customer_Acq)
df.loc[df['Age']<18,'Age'] = df.Age.mean()
df
# Out:
#      No Customer    Age        City   Product     Limit Company        Segment
# 0     1       A1  76.00   BANGALORE      Gold  500000.0      C1  Self Employed
# 1     2       A2  71.00    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2     3       A3  34.00      COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3     4       A4  47.00      BOMBAY  Platimum   10001.0      C4           Govt
# 4     5       A5  56.00   BANGALORE  Platimum   10002.0      C5  Normal Salary
# 5     6       A6  70.00       DELHI    Silver  100000.0      C6  Self Employed
# 6     7       A7  26.00      COCHIN    Silver  100001.0      C7   Salaried_MNC
# 7     8       A8  67.00       PATNA    Silver  100002.0      C8   Salaried_Pvt
# 8     9       A9  79.00     CHENNAI    Silver  100003.0      C9           Govt
# 9    10      A10  54.00    CALCUTTA      Gold  500000.0     C10  Normal Salary
# 10   11      A11  35.00      COCHIN      Gold  500000.0     C11  Normal Salary
# 11   12      A12  51.00      BOMBAY      Gold  500000.0     C12  Self Employed
# 12   13      A13  29.00   BANGALORE      Gold  500000.0     C13   Salaried_MNC
# 13   14      A14  46.49   BANGALORE      Gold  500000.0     C14   Salaried_Pvt
# 14   15      A15  25.00    CALCUTTA      Gold  500000.0     C15           Govt
# 15   16      A16  52.00      COCHIN      Gold  500000.0     C16  Normal Salary
# 16   17      A17  78.00      BOMBAY      Gold  500000.0     C17  Self Employed
# 17   18      A18  34.00   BANGALORE    Silver  100000.0     C18   Salaried_MNC
# 18   19      A19  27.00   BANGALORE  Platimum   10000.0     C19   Salaried_Pvt
# 19   20      A20  27.00    CALCUTTA  Platimum   10001.0     C20           Govt
# 20   21      A21  57.00      COCHIN  Platimum   10002.0     C21  Normal Salary
# 21   22      A22  27.00      BOMBAY    Silver  100000.0     C22  Self Employed
# 22   23      A23  51.00   BANGALORE    Silver  100001.0      C5   Salaried_MNC
# 23   24      A24  53.00       DELHI    Silver  100002.0      C6   Salaried_Pvt
# 24   25      A25  35.00      COCHIN    Silver  100003.0      C7           Govt
# 25   26      A26  38.00       PATNA      Gold  500000.0      C8  Normal Salary
# 26   27      A27  24.00     CHENNAI      Gold  500000.0      C9  Self Employed
# 27   28      A28  36.00  TRIVANDRUM      Gold  500000.0     C10   Salaried_MNC
# 28   29      A29  72.00    CALCUTTA      Gold  500000.0     C11   Salaried_Pvt
# 29   30      A30  25.00   BANGALORE      Gold  500000.0     C12           Govt
# ..  ...      ...    ...         ...       ...       ...     ...            ...
# 70   71      A71  34.00      BOMBAY  Platimum   10002.0     C33  Self Employed
# 71   72      A72  63.00   BANGALORE    Silver  100000.0     C34  Self Employed
# 72   73      A73  75.00    CALCUTTA    Silver  100001.0     C35  Self Employed
# 73   74      A74  51.00      COCHIN    Silver  100002.0     C36  Self Employed
# 74   75      A75  36.00      BOMBAY    Silver  100003.0     C37  Self Employed
# 75   76      A76  66.00   BANGALORE    Silver  500000.0     C38  Self Employed
# 76   77      A77  35.00   BANGALORE    Silver  500000.0     C39  Self Employed
# 77   78      A78  71.00    CALCUTTA    Silver  500000.0     C40  Self Employed
# 78   79      A79  60.00      COCHIN    Silver  500000.0     C41           Govt
# 79   80      A80  39.00      BOMBAY    Silver  500000.0      C3           Govt
# 80   81      A81  65.00   BANGALORE      Gold  500000.0      C4           Govt
# 81   82      A82  52.00       DELHI      Gold  500000.0      C5           Govt
# 82   83      A83  37.00      COCHIN  Platimum   10002.0      C6           Govt
# 83   84      A84  70.00       PATNA    Silver  100000.0      C7           Govt
# 84   85      A85  59.00     CHENNAI    Silver  100001.0      C8           Govt
# 85   86      A86  25.00  TRIVANDRUM    Silver  100002.0      C9           Govt
# 86   87      A87  27.00    CALCUTTA    Silver  100003.0     C10           Govt
# 87   88      A88  63.00   BANGALORE      Gold  500000.0     C11           Govt
# 88   89      A89  72.00    CALCUTTA      Gold  500000.0     C12           Govt
# 89   90      A90  46.49      COCHIN      Gold  500000.0     C13           Govt
# 90   91      A91  41.00      BOMBAY      Gold  500000.0     C14           Govt
# 91   92      A92  78.00   BANGALORE      Gold  500000.0     C15           Govt
# 92   93      A93  56.00       DELHI      Gold  500000.0     C16           Govt
# 93   94      A94  31.00      COCHIN      Gold  500000.0     C17           Govt
# 94   95      A95  62.00       PATNA      Gold  500000.0     C18   Salaried_MNC
# 95   96      A96  54.00     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96   97      A97  58.00  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97   98      A98  51.00    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98   99      A99  35.00    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99  100     A100  36.00      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# [100 rows x 8 columns]

# %% [markdown]
# ### b. In case spend amount is more than the limit, replace it with 50% of that customer’s limit.

# %%
Spend_amt = pd.read_csv('spend.csv')

# %%
#Merging Spend and Customer Acquistion csv files
df1 = pd.merge(left = Customer_Acq,
               right = Spend_amt,
               left_on = 'Customer',
               right_on = 'Customer',
               how = 'inner',
               indicator = True)
Cust_limit = 0.50*df1.Limit
df1.loc[df1['Amount']>df1['Limit'],['Amount','Limit']] = Cust_limit
df1
# Out:
#        No Customer    Age        City   Product     Limit Company  \
# 0       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 5       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 6       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 7       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 8       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 9       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 10      1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 11      1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 12      1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 13      1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 14      1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 15      1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 16      1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 17      1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 18      2       A2  71.00    CALCUTTA    Silver   50000.0      C2
# 19      2       A2  71.00    CALCUTTA    Silver   50000.0      C2
# 20      2       A2  71.00    CALCUTTA    Silver   50000.0      C2
# 21      2       A2  71.00    CALCUTTA    Silver   50000.0      C2
# 22      2       A2  71.00    CALCUTTA    Silver   50000.0      C2
# 23      2       A2  71.00    CALCUTTA    Silver  100000.0      C2
# 24      2       A2  71.00    CALCUTTA    Silver   50000.0      C2
# 25      2       A2  71.00    CALCUTTA    Silver   50000.0      C2
# 26      2       A2  71.00    CALCUTTA    Silver   50000.0      C2
# 27      2       A2  71.00    CALCUTTA    Silver   50000.0      C2
# 28      2       A2  71.00    CALCUTTA    Silver   50000.0      C2
# 29      3       A3  34.00      COCHIN  Platimum    5000.0      C3
# ...   ...      ...    ...         ...       ...       ...     ...
# 1470   71      A71  34.00      BOMBAY  Platimum    5001.0     C33
# 1471   72      A72  63.00   BANGALORE    Silver   50000.0     C34
# 1472   73      A73  75.00    CALCUTTA    Silver  100001.0     C35
# 1473   74      A74  51.00      COCHIN    Silver   50001.0     C36
# 1474   75      A75  36.00      BOMBAY    Silver   50001.5     C37
# 1475   76      A76  66.00   BANGALORE    Silver  500000.0     C38
# 1476   77      A77  35.00   BANGALORE    Silver  500000.0     C39
# 1477   78      A78  71.00    CALCUTTA    Silver  500000.0     C40
# 1478   79      A79  60.00      COCHIN    Silver  500000.0     C41
# 1479   80      A80  39.00      BOMBAY    Silver  500000.0      C3
# 1480   81      A81  65.00   BANGALORE      Gold  500000.0      C4
# 1481   82      A82  52.00       DELHI      Gold  500000.0      C5
# 1482   83      A83  37.00      COCHIN  Platimum    5001.0      C6
# 1483   84      A84  70.00       PATNA    Silver   50000.0      C7
# 1484   85      A85  59.00     CHENNAI    Silver   50000.5      C8
# 1485   86      A86  25.00  TRIVANDRUM    Silver   50001.0      C9
# 1486   87      A87  27.00    CALCUTTA    Silver   50001.5     C10
# 1487   88      A88  63.00   BANGALORE      Gold  500000.0     C11
# 1488   89      A89  72.00    CALCUTTA      Gold  500000.0     C12
# 1489   90      A90  46.49      COCHIN      Gold  500000.0     C13
# 1490   91      A91  41.00      BOMBAY      Gold  500000.0     C14
# 1491   92      A92  78.00   BANGALORE      Gold  500000.0     C15
# 1492   93      A93  56.00       DELHI      Gold  500000.0     C16
# 1493   94      A94  31.00      COCHIN      Gold  500000.0     C17
# 1494   95      A95  62.00       PATNA      Gold  500000.0     C18
# 1495   96      A96  54.00     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.00  TRIVANDRUM  Platimum    5000.0     C20
# 1497   98      A98  51.00    CALCUTTA  Platimum    5000.5     C21
# 1498   99      A99  35.00    CALCUTTA  Platimum    5001.0     C22
# 1499  100     A100  36.00      COCHIN    Silver   50000.0      C5
#
#             Segment  Sl No:      Month          Type     Amount _merge
# 0     Self Employed       1  12-Jan-04     JEWELLERY  485470.80   both
# 1     Self Employed       2   3-Jan-04         PETRO  410556.13   both
# 2     Self Employed       3  15-Jan-04       CLOTHES   23740.46   both
# 3     Self Employed       4  25-Jan-04          FOOD  484342.47   both
# 4     Self Employed       5  17-Jan-05        CAMERA  369694.07   both
# 5     Self Employed       6  23-Feb-05       SANDALS  168285.60   both
# 6     Self Employed       7   1-Feb-05           CAR   23370.20   both
# 7     Self Employed     103  12-Jan-04  TRAIN TICKET  440563.22   both
# 8     Self Employed     117   5-Feb-04    BUS TICKET   52208.65   both
# 9     Self Employed     131  19-Apr-06    AIR TICKET  346925.68   both
# 10    Self Employed     145  22-Nov-05         PETRO  183839.61   both
# 11    Self Employed     159   3-Aug-05  MOVIE TICKET  344372.10   both
# 12    Self Employed     173   3-Oct-06        RENTAL  244534.68   both
# 13    Self Employed     187   3-Feb-05          FOOD  155611.91   both
# 14    Self Employed     201   2-Apr-06  TRAIN TICKET  176372.82   both
# 15    Self Employed     215  25-Jan-04  TRAIN TICKET  394970.96   both
# 16    Self Employed     229  23-Feb-05       CLOTHES  476702.09   both
# 17    Self Employed     243   5-May-04    BUS TICKET  361141.31   both
# 18     Salaried_MNC     104   3-Jan-04        RENTAL   50000.00   both
# 19     Salaried_MNC     118  28-Feb-05  TRAIN TICKET   50000.00   both
# 20     Salaried_MNC     132   6-Apr-04    BUS TICKET   50000.00   both
# 21     Salaried_MNC     146  23-Nov-04         PETRO   50000.00   both
# 22     Salaried_MNC     160   3-Sep-05     JEWELLERY   50000.00   both
# 23     Salaried_MNC     174   3-Nov-06  MOVIE TICKET   75728.35   both
# 24     Salaried_MNC     188   4-Feb-06          FOOD   50000.00   both
# 25     Salaried_MNC     202   3-Apr-06        RENTAL   50000.00   both
# 26     Salaried_MNC     216  12-Jan-04        RENTAL   50000.00   both
# 27     Salaried_MNC     230   3-Feb-05       CLOTHES   50000.00   both
# 28     Salaried_MNC     244   6-May-06  TRAIN TICKET   50000.00   both
# 29     Salaried_Pvt     105  15-Jan-04  MOVIE TICKET    5000.00   both
# ...             ...     ...        ...           ...        ...    ...
# 1470  Self Employed    1500  24-Mar-06    BUS TICKET    5001.00   both
# 1471  Self Employed      74   5-Feb-04    AIR TICKET   50000.00   both
# 1472  Self Employed      75  28-Feb-05    AIR TICKET   47380.56   both
# 1473  Self Employed      76  16-Feb-05    AIR TICKET   50001.00   both
# 1474  Self Employed      77  23-Feb-05    AIR TICKET   50001.50   both
# 1475  Self Employed      78   3-Feb-05    AIR TICKET   30066.44   both
# 1476  Self Employed      79   4-Feb-06    AIR TICKET   31048.93   both
# 1477  Self Employed      80  25-Mar-06        CAMERA  432217.57   both
# 1478           Govt      81  31-Mar-06       SANDALS  405913.14   both
# 1479           Govt      82  23-Mar-06           CAR  474797.30   both
# 1480           Govt      83  24-Mar-06          BIKE  175659.72   both
# 1481           Govt      84  25-Mar-06          AUTO  379401.53   both
# 1482           Govt      85  26-Mar-06      SHOPPING    5001.00   both
# 1483           Govt      86  27-Mar-06    AIR TICKET   50000.00   both
# 1484           Govt      87  28-Mar-06    BUS TICKET   50000.50   both
# 1485           Govt      88  29-Mar-06  TRAIN TICKET   50001.00   both
# 1486           Govt      89  30-Mar-06        RENTAL   50001.50   both
# 1487           Govt      90  31-Mar-06  MOVIE TICKET   26518.91   both
# 1488           Govt      91   1-Apr-06     JEWELLERY   24972.02   both
# 1489           Govt      92   2-Apr-06         PETRO  264882.27   both
# 1490           Govt      93   3-Apr-06       CLOTHES   89951.84   both
# 1491           Govt      94   4-Apr-06          FOOD  341858.87   both
# 1492           Govt      95  12-Jan-04        CAMERA  297505.09   both
# 1493           Govt      96   3-Jan-04       SANDALS  312714.37   both
# 1494   Salaried_MNC      97  15-Jan-04           CAR  240401.50   both
# 1495   Salaried_Pvt      98  25-Jan-04          BIKE   54729.66   both
# 1496           Govt      99  12-Jan-04          AUTO    5000.00   both
# 1497  Normal Salary     100   3-Jan-04      SHOPPING    5000.50   both
# 1498  Self Employed     101  15-Jan-04    AIR TICKET    5001.00   both
# 1499   Salaried_MNC     102  25-Jan-04    BUS TICKET   50000.00   both
#
# [1500 rows x 13 columns]

# %% [markdown]
# ### c. Incase the repayment amount is more than the limit, replace the repayment with the limit.

# %%
Repayment = pd.read_csv('Repayment.csv')

# %%
#Merging Repayment and Customer Acquistion csv files
df2 = pd.merge(left = Customer_Acq,
               right = Repayment,
               left_on = 'Customer',
               right_on = 'Customer',
               how = 'inner',
               indicator = True)
df2.drop(df2.columns[11],axis=1)

df2.loc[df2['Amount']>df2['Limit'],['Amount','Limit']] = df2.Limit
df2
# Out:
#        No Customer    Age        City   Product     Limit Company  \
# 0       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 5       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 6       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 7       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 8       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 9       1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 10      1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 11      1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 12      1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 13      1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 14      1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 15      1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 16      1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 17      1       A1  76.00   BANGALORE      Gold  500000.0      C1
# 18      2       A2  71.00    CALCUTTA    Silver  100000.0      C2
# 19      2       A2  71.00    CALCUTTA    Silver  100000.0      C2
# 20      2       A2  71.00    CALCUTTA    Silver  100000.0      C2
# 21      2       A2  71.00    CALCUTTA    Silver  100000.0      C2
# 22      2       A2  71.00    CALCUTTA    Silver  100000.0      C2
# 23      2       A2  71.00    CALCUTTA    Silver  100000.0      C2
# 24      2       A2  71.00    CALCUTTA    Silver  100000.0      C2
# 25      2       A2  71.00    CALCUTTA    Silver  100000.0      C2
# 26      2       A2  71.00    CALCUTTA    Silver  100000.0      C2
# 27      2       A2  71.00    CALCUTTA    Silver  100000.0      C2
# 28      2       A2  71.00    CALCUTTA    Silver  100000.0      C2
# 29      3       A3  34.00      COCHIN  Platimum   10000.0      C3
# ...   ...      ...    ...         ...       ...       ...     ...
# 1470   71      A71  34.00      BOMBAY  Platimum   10002.0     C33
# 1471   72      A72  63.00   BANGALORE    Silver  100000.0     C34
# 1472   73      A73  75.00    CALCUTTA    Silver  100001.0     C35
# 1473   74      A74  51.00      COCHIN    Silver  100002.0     C36
# 1474   75      A75  36.00      BOMBAY    Silver  100003.0     C37
# 1475   76      A76  66.00   BANGALORE    Silver  500000.0     C38
# 1476   77      A77  35.00   BANGALORE    Silver  500000.0     C39
# 1477   78      A78  71.00    CALCUTTA    Silver  500000.0     C40
# 1478   79      A79  60.00      COCHIN    Silver  500000.0     C41
# 1479   80      A80  39.00      BOMBAY    Silver  500000.0      C3
# 1480   81      A81  65.00   BANGALORE      Gold  500000.0      C4
# 1481   82      A82  52.00       DELHI      Gold  500000.0      C5
# 1482   83      A83  37.00      COCHIN  Platimum   10002.0      C6
# 1483   84      A84  70.00       PATNA    Silver  100000.0      C7
# 1484   85      A85  59.00     CHENNAI    Silver  100001.0      C8
# 1485   86      A86  25.00  TRIVANDRUM    Silver  100002.0      C9
# 1486   87      A87  27.00    CALCUTTA    Silver  100003.0     C10
# 1487   88      A88  63.00   BANGALORE      Gold  500000.0     C11
# 1488   89      A89  72.00    CALCUTTA      Gold  500000.0     C12
# 1489   90      A90  46.49      COCHIN      Gold  500000.0     C13
# 1490   91      A91  41.00      BOMBAY      Gold  500000.0     C14
# 1491   92      A92  78.00   BANGALORE      Gold  500000.0     C15
# 1492   93      A93  56.00       DELHI      Gold  500000.0     C16
# 1493   94      A94  31.00      COCHIN      Gold  500000.0     C17
# 1494   95      A95  62.00       PATNA      Gold  500000.0     C18
# 1495   96      A96  54.00     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.00  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.00    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.00    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.00      COCHIN    Silver  100000.0      C5
#
#             Segment  SL No:      Month     Amount _merge
# 0     Self Employed       1  12-Jan-04  495414.75   both
# 1     Self Employed       2   3-Jan-04  245899.02   both
# 2     Self Employed       3  15-Jan-04  259490.06   both
# 3     Self Employed       4  25-Jan-04  437555.12   both
# 4     Self Employed       5  17-Jan-05  165972.88   both
# 5     Self Employed       6  23-Feb-05  365366.62   both
# 6     Self Employed       7   1-Feb-05   14473.41   both
# 7     Self Employed     103  12-Jan-04  350446.82   both
# 8     Self Employed     117   5-Feb-04  117964.43   both
# 9     Self Employed     131  19-Apr-06   79849.19   both
# 10    Self Employed     145  22-Nov-05  402099.78   both
# 11    Self Employed     159  21-Nov-06  169358.40   both
# 12    Self Employed     173   3-Jul-05  297176.74   both
# 13    Self Employed     187   3-Sep-06  186427.50   both
# 14    Self Employed     201  23-Feb-05   96670.70   both
# 15    Self Employed     215   1-Apr-06  429099.97   both
# 16    Self Employed     229  15-Jan-04  453027.64   both
# 17    Self Employed     243  16-Feb-05  187398.64   both
# 18     Salaried_MNC     104   3-Jan-04  100000.00   both
# 19     Salaried_MNC     118  28-Feb-05  100000.00   both
# 20     Salaried_MNC     132   6-Apr-04  100000.00   both
# 21     Salaried_MNC     146  23-Nov-04  100000.00   both
# 22     Salaried_MNC     160  22-Nov-05   10274.00   both
# 23     Salaried_MNC     174   3-Aug-05  100000.00   both
# 24     Salaried_MNC     188   3-Oct-06  100000.00   both
# 25     Salaried_MNC     202   3-Feb-05  100000.00   both
# 26     Salaried_MNC     216   2-Apr-06  100000.00   both
# 27     Salaried_MNC     230  25-Jan-04  100000.00   both
# 28     Salaried_MNC     244  23-Feb-05  100000.00   both
# 29     Salaried_Pvt     105  15-Jan-04   10000.00   both
# ...             ...     ...        ...        ...    ...
# 1470  Self Employed    1500  13-Sep-04   10002.00   both
# 1471  Self Employed      74   5-Feb-04  100000.00   both
# 1472  Self Employed      75  28-Feb-05  100001.00   both
# 1473  Self Employed      76  16-Feb-05  100002.00   both
# 1474  Self Employed      77  23-Feb-05  100003.00   both
# 1475  Self Employed      78   3-Feb-05  265619.05   both
# 1476  Self Employed      79   4-Feb-06    3159.62   both
# 1477  Self Employed      80  25-Mar-06   55344.81   both
# 1478           Govt      81  31-Mar-06  193230.31   both
# 1479           Govt      82  23-Mar-06  481205.64   both
# 1480           Govt      83  24-Mar-06  207780.32   both
# 1481           Govt      84  25-Mar-06  342200.74   both
# 1482           Govt      85  26-Mar-06   10002.00   both
# 1483           Govt      86  27-Mar-06  100000.00   both
# 1484           Govt      87  28-Mar-06  100001.00   both
# 1485           Govt      88  29-Mar-06  100002.00   both
# 1486           Govt      89  30-Mar-06  100003.00   both
# 1487           Govt      90  31-Mar-06  146821.30   both
# 1488           Govt      91   1-Apr-06  497237.97   both
# 1489           Govt      92   2-Apr-06  109931.32   both
# 1490           Govt      93   3-Apr-06  247781.00   both
# 1491           Govt      94   4-Apr-06  459105.69   both
# 1492           Govt      95  12-Jan-04  342326.14   both
# 1493           Govt      96   3-Jan-04  153465.89   both
# 1494   Salaried_MNC      97  15-Jan-04  369405.96   both
# 1495   Salaried_Pvt      98  25-Jan-04  100000.00   both
# 1496           Govt      99  12-Jan-04   10000.00   both
# 1497  Normal Salary     100   3-Jan-04   10001.00   both
# 1498  Self Employed     101  15-Jan-04   10002.00   both
# 1499   Salaried_MNC     102  25-Jan-04   69551.19   both
#
# [1500 rows x 12 columns]

# %% [markdown]
# ## Q2. From the above dataset create the following summaries:
#
#
# ### a. How many distinct customers exist?

# %%
Customer_Acq.Customer.nunique()
# Out:
# 100

# %% [markdown]
# ### b. How many distinct categories exist?

# %%
print("Product ",df1.Product.nunique())
print("Segment",df1.Segment.nunique())
print("Type",df1.Type.nunique())
# Out:
# Product  3
# Segment 5
# Type 15

# %% [markdown]
# ### c. What is the average monthly spend by customers?

# %%
df1['Month'] = pd.to_datetime(Repayment['Month'])
df1['month'] = df1['Month'].dt.month
g = df1.groupby(["Customer","month"])['Amount'].mean()
display(g)
# Out:
# Customer  month
# A1        1        354760.786000
#           2        225512.467500
#           3        312959.818000
# A10       5        260154.826667
#           7        369222.510000
#           8        143632.145000
#           9        239798.030000
#           11        60130.967500
# A100      9         50000.000000
# A11       5        239390.663750
#           6        190703.270000
#           7        263577.250000
#           8        468501.450000
#           9        307622.010000
#           11       247572.965000
# A12       1        301869.308333
#           2        237952.710000
#           3        258178.510000
#           4        350004.390000
#           5        460555.540000
#           6        214891.010000
#           7        104548.340000
#           8        383087.290000
#           9        116561.350000
#           10       290141.790000
#           11        75917.000000
#           12       488699.010000
# A13       1        261155.681667
#           3        270222.306667
#           4        274701.057500
#                        ...
# A76       2         30066.440000
# A77       2         31048.930000
# A78       2        432217.570000
# A79       2        405913.140000
# A8        1         47109.572500
#           2         47533.518333
# A80       2        474797.300000
# A81       3        175659.720000
# A82       3        379401.530000
# A83       3          5001.000000
# A84       3         50000.000000
# A85       3         50000.500000
# A86       4         50001.000000
# A87       4         50001.500000
# A88       4         26518.910000
# A89       4         24972.020000
# A9        2         44135.720000
#           3         43001.310000
#           4         48026.911667
#           5         62616.246000
# A90       4        264882.270000
# A91       4         89951.840000
# A92       5        341858.870000
# A93       5        297505.090000
# A94       5        312714.370000
# A95       5        240401.500000
# A96       5         54729.660000
# A97       5          5000.000000
# A98       7          5000.500000
# A99       8          5001.000000
# Name: Amount, Length: 405, dtype: float64

# %% [markdown]
# ### d. What is the average monthly repayment by customers?

# %%
df2['Month'] = pd.to_datetime(df1['Month'])
df2['month'] = df1['Month'].dt.month
g = df1.groupby(["Customer","month"])['Amount'].mean()
display(g)
# Out:
# Customer  month
# A1        1        354760.786000
#           2        225512.467500
#           3        312959.818000
# A10       5        260154.826667
#           7        369222.510000
#           8        143632.145000
#           9        239798.030000
#           11        60130.967500
# A100      9         50000.000000
# A11       5        239390.663750
#           6        190703.270000
#           7        263577.250000
#           8        468501.450000
#           9        307622.010000
#           11       247572.965000
# A12       1        301869.308333
#           2        237952.710000
#           3        258178.510000
#           4        350004.390000
#           5        460555.540000
#           6        214891.010000
#           7        104548.340000
#           8        383087.290000
#           9        116561.350000
#           10       290141.790000
#           11        75917.000000
#           12       488699.010000
# A13       1        261155.681667
#           3        270222.306667
#           4        274701.057500
#                        ...
# A76       2         30066.440000
# A77       2         31048.930000
# A78       2        432217.570000
# A79       2        405913.140000
# A8        1         47109.572500
#           2         47533.518333
# A80       2        474797.300000
# A81       3        175659.720000
# A82       3        379401.530000
# A83       3          5001.000000
# A84       3         50000.000000
# A85       3         50000.500000
# A86       4         50001.000000
# A87       4         50001.500000
# A88       4         26518.910000
# A89       4         24972.020000
# A9        2         44135.720000
#           3         43001.310000
#           4         48026.911667
#           5         62616.246000
# A90       4        264882.270000
# A91       4         89951.840000
# A92       5        341858.870000
# A93       5        297505.090000
# A94       5        312714.370000
# A95       5        240401.500000
# A96       5         54729.660000
# A97       5          5000.000000
# A98       7          5000.500000
# A99       8          5001.000000
# Name: Amount, Length: 405, dtype: float64

# %% [markdown]
# ### e. If the monthly rate of interest is 2.9%, what is the profit for the bank for each month?

# %% [markdown]
# ### f. What are the top 5 product types?

# %%
Top_5 = Spend_amt.groupby('Type').sum().sort_values("Amount",ascending = False).head(5)
t = (Top_5).reset_index()
display(t)
# Out:
#            Type  Sl No:       Amount
# 0         PETRO  146920  49863174.09
# 1        CAMERA  113612  41481571.96
# 2          FOOD  110164  37773338.43
# 3  TRAIN TICKET   90087  33067077.15
# 4    AIR TICKET  117877  32955445.42

# %% [markdown]
# ### g. Which city is having maximum spend?

# %%
group_city = df1.groupby(['City'])['Amount'].sum()
group_city.nlargest(1)
# Out:
# City
# COCHIN    45963513.5
# Name: Amount, dtype: float64

# %% [markdown]
# ### h. Which age group is spending more money?

# %%
group_age = df1.groupby('Age').sum()
amount_spend =  group_age['Amount']
amount_spend.nlargest(1)
# Out:
# Age
# 28.0    17365270.23
# Name: Amount, dtype: float64

# %% [markdown]
# ### i. Who are the top 10 customers in terms of repayment?

# %%
Top_10 = df2.groupby('Customer').sum().sort_values("Amount",ascending = False).head(10)
t = (Top_10).reset_index()
display(t)
# Out:
#   Customer    No      Age       Limit  SL No:       Amount  month
# 0      A61  2318  1672.00  19000000.0   45502  10539142.91    206
# 1      A60  2280  1064.00  19000000.0   45464   9876290.74    185
# 2      A13   403   899.00  15500000.0   10148   9572000.66     61
# 3      A43  1333   651.00  15500000.0   31424   8489871.46    190
# 4      A45  1395  2077.00  15500000.0   31486   8448334.87     69
# 5      A12   372  1581.00  15500000.0   10117   8334760.16    147
# 6      A14   434  1441.19  15500000.0   10179   7943268.63    112
# 7      A44  1364   868.00  15500000.0   31455   7744730.12    171
# 8      A39  1209  2418.00  15500000.0   31300   7622483.30    179
# 9      A42  1302  1550.00  15500000.0   31393   7615460.86     58

# %% [markdown]
# ## Q3. Calculate the city wise spend on each product on yearly basis. Also include a graphical representation for the same.

# %%
df1['Month'] = pd.to_datetime(df1['Month'])
df1['year'] = df1['Month'].dt.year
g = df1.groupby(["City","Product","year"])             
tot_amount = g[["Amount"]].sum().add_prefix("Total_")
# sns.barplot(x=g,y = tot_amount,hue = "Product",data = tot_amount)

# %% [markdown]
# ## Q4. Create graphs for -
#
# ### a. Monthly comparison of total spends, city wise

# %%
# sns.set()
# pd.pivot_table(df1, index ='Month',columns = 'City',values = 'Amount').plot(kind='bar')
# plt.ylabel("Total amount spend")
df1['Month'] = pd.to_datetime(df1['Month'])
df1['month'] = df1['Month'].dt.month
sns.set()
pd.pivot_table(df1, index ='City',columns ='month',values="Amount").plot(kind='bar')
plt.ylabel('Total amount spend')
# Out:
# Text(0, 0.5, 'Total amount spend')

# %% [markdown]
# ### b. Comparison of yearly spend on air tickets

# %%
df1['Month'] = pd.to_datetime(df1['Month'])
df1['Year'] = df1['Month'].dt.year

sns.set()
pd.pivot_table(df1, index ='City',columns ='Year',values="Amount").plot(kind='bar')
plt.ylabel('Total amount spend')
# Out:
# Text(0, 0.5, 'Total amount spend')

# %% [markdown]
# ### c. Comparison of monthly spend for each product

# %% [markdown]
# ## Q5.Write user defined PYTHON function to perform the following analysis:

# %%
def top_customers():
    prod = input("Enter product name : ")
    time = input("Enter year  : ")
    Top_10 = df2.groupby(['Customer','City']).sum().sort_values("Amount",ascending = False).head(10)
    return Top_10

# %%
top_customers()
# Out:
# Enter product name : asdasd
# Enter year  : asdad
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-27daf00c4b6a> in <module>
# ----> 1 top_customers()
#
# <ipython-input-28-667e440d24f0> in top_customers()
#       2     prod = input("Enter product name : ")
#       3     time = input("Enter year  : ")
# ----> 4     Top_10 = df2.groupby(['Customer','City']).sum().sort_values("Amount",ascending = False).head(10)
#       5     return Top_10
#
# NameError: name 'df2' is not defined
